# %%
name='Abdul Azeem Khan'

# %%
len(name)
# Out:
# 16

# %%
name[0]
# Out:
# 'A'

# %%
name[3]
# Out:
# 'u'

# %%
name[16] #index error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\data analytics\strings.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/data%20analytics/strings.ipynb#ch0000005?line=0'>1</a> name[16]
#
# IndexError: string index out of range

# %%
name[0]+name[1]+name[2]+name[3]+name[4]
# Out:
# 'Abdul'

# %%
for i in range(5):
    print(name[i],end='')
# Out:
# Abdul

# %%
name[-1]
# Out:
# 'n'

# %%
name[-1]+name[-2]+name[-3]
# Out:
# 'nah'

# %%
#getting a slice
s='digipodium'
slice1=s[4:7]
print(slice1)
# Out:
# pod

# %%
fname=name[0:5]
print(fname)
# Out:
# Abdul

# %%
name='Vijay Deenanath Chauhan'

# %%
name.index("D")
# Out:
# 6

# %%
print(name[6:15])
# Out:
# Deenanath

# %%
name[-7:len(name)]
# Out:
# 'Chauhan'

# %%
s='digipodium'
slice1=s[0:4]
slice2=s[:4]
print(slice1)
print(slice2)
# Out:
# digi
# digi

# %%
s='digipodium'
slice1=s[4:len(s)]
slice2=s[4:]
print(slice1)
print(slice2)
# Out:
# podium
# podium

# %%
#chr() converts integer to string char
x=chr(65)
print(x)
# Out:
# A

# %%
x=chr(8987)
print(x)
# Out:
# ⌛

# %%
x=chr(12365)
print(x)
# Out:
# き

# %%
for i in range(160000):
    print(chr(i),end="")
# Out:
# 𒌁𒌂𒌃𒌄𒌅𒌆𒌇𒌈𒌉𒌊𒌋𒌌𒌍𒌎𒌏𒌐𒌑𒌒𒌓𒌔𒌕𒌖𒌗𒌘𒌙𒌚𒌛𒌜𒌝𒌞𒌟𒌠𒌡𒌢𒌣𒌤𒌥𒌦𒌧𒌨𒌩𒌪𒌫𒌬𒌭𒌮𒌯𒌰𒌱𒌲𒌳𒌴𒌵𒌶𒌷𒌸𒌹𒌺𒌻𒌼𒌽𒌾𒌿𒍀𒍁𒍂𒍃𒍄𒍅𒍆𒍇𒍈𒍉𒍊𒍋𒍌𒍍𒍎𒍏𒍐𒍑𒍒𒍓𒍔𒍕𒍖𒍗𒍘𒍙𒍚𒍛𒍜𒍝𒍞𒍟𒍠𒍡𒍢𒍣𒍤𒍥𒍦𒍧𒍨𒍩𒍪𒍫𒍬𒍭𒍮𒍯𒍰𒍱𒍲𒍳𒍴𒍵𒍶𒍷𒍸𒍹𒍺𒍻𒍼𒍽𒍾𒍿𒎀𒎁𒎂𒎃𒎄𒎅𒎆𒎇𒎈𒎉𒎊𒎋𒎌𒎍𒎎𒎏𒎐𒎑𒎒𒎓𒎔𒎕𒎖𒎗𒎘𒎙𒎚𒎛𒎜𒎝𒎞𒎟𒎠𒎡𒎢𒎣𒎤𒎥𒎦𒎧𒎨𒎩𒎪𒎫𒎬𒎭𒎮𒎯𒎰𒎱𒎲𒎳𒎴𒎵𒎶𒎷𒎸𒎹𒎺𒎻𒎼𒎽𒎾𒎿𒏀𒏁𒏂𒏃𒏄𒏅𒏆𒏇𒏈𒏉𒏊𒏋𒏌𒏍𒏎𒏏𒏐𒏑𒏒𒏓𒏔𒏕𒏖𒏗𒏘𒏙𒏚𒏛𒏜𒏝𒏞𒏟𒏠𒏡𒏢𒏣𒏤𒏥𒏦𒏧𒏨𒏩𒏪𒏫𒏬𒏭𒏮𒏯𒏰𒏱𒏲𒏳𒏴𒏵𒏶𒏷𒏸𒏹𒏺𒏻𒏼𒏽𒏾𒏿𒐀𒐁𒐂𒐃𒐄𒐅𒐆𒐇𒐈𒐉𒐊𒐋𒐌𒐍𒐎𒐏𒐐𒐑𒐒𒐓𒐔𒐕𒐖𒐗𒐘𒐙𒐚𒐛𒐜𒐝𒐞𒐟𒐠𒐡𒐢𒐣𒐤𒐥𒐦𒐧𒐨𒐩𒐪𒐫𒐬𒐭𒐮𒐯𒐰𒐱𒐲𒐳𒐴𒐵𒐶𒐷𒐸𒐹𒐺𒐻𒐼𒐽𒐾𒐿𒑀𒑁𒑂𒑃𒑄𒑅𒑆𒑇𒑈𒑉𒑊𒑋𒑌𒑍𒑎𒑏𒑐𒑑𒑒𒑓𒑔𒑕𒑖𒑗𒑘𒑙𒑚𒑛𒑜𒑝𒑞𒑟𒑠𒑡𒑢𒑣𒑤𒑥𒑦𒑧𒑨𒑩𒑪𒑫𒑬𒑭𒑮𒑯𒑰𒑱𒑲𒑳𒑴𒑵𒑶𒑷𒑸𒑹𒑺𒑻𒑼𒑽𒑾𒑿𒒀𒒁𒒂𒒃𒒄𒒅𒒆𒒇𒒈𒒉𒒊𒒋𒒌𒒍𒒎𒒏𒒐𒒑𒒒𒒓𒒔𒒕𒒖𒒗𒒘𒒙𒒚𒒛𒒜𒒝𒒞𒒟𒒠𒒡𒒢𒒣𒒤𒒥𒒦𒒧𒒨𒒩𒒪𒒫𒒬𒒭𒒮𒒯𒒰𒒱𒒲𒒳𒒴𒒵𒒶𒒷𒒸𒒹𒒺𒒻𒒼𒒽𒒾𒒿𒓀𒓁𒓂𒓃𒓄𒓅𒓆𒓇𒓈𒓉𒓊𒓋𒓌𒓍𒓎𒓏𒓐𒓑𒓒𒓓𒓔𒓕𒓖𒓗𒓘𒓙𒓚𒓛𒓜𒓝𒓞𒓟𒓠𒓡𒓢𒓣𒓤𒓥𒓦𒓧𒓨𒓩𒓪𒓫𒓬𒓭𒓮𒓯𒓰𒓱𒓲𒓳𒓴𒓵𒓶𒓷𒓸𒓹𒓺𒓻𒓼𒓽𒓾𒓿𒔀𒔁𒔂𒔃𒔄𒔅𒔆𒔇𒔈𒔉𒔊𒔋𒔌𒔍𒔎𒔏𒔐𒔑𒔒𒔓𒔔𒔕𒔖𒔗𒔘𒔙𒔚𒔛𒔜𒔝𒔞𒔟𒔠𒔡𒔢𒔣𒔤𒔥𒔦𒔧𒔨𒔩𒔪𒔫𒔬𒔭𒔮𒔯𒔰𒔱𒔲𒔳𒔴𒔵𒔶𒔷𒔸𒔹𒔺𒔻𒔼𒔽𒔾𒔿𒕀𒕁𒕂𒕃𒕄𒕅𒕆𒕇𒕈𒕉𒕊𒕋𒕌𒕍𒕎𒕏𒕐𒕑𒕒𒕓𒕔𒕕𒕖𒕗𒕘𒕙𒕚𒕛𒕜𒕝𒕞𒕟𒕠𒕡𒕢𒕣𒕤𒕥𒕦𒕧𒕨𒕩𒕪𒕫𒕬𒕭𒕮𒕯𒕰𒕱𒕲𒕳𒕴𒕵𒕶𒕷𒕸𒕹𒕺𒕻𒕼𒕽𒕾𒕿𒖀𒖁𒖂𒖃𒖄𒖅𒖆𒖇𒖈𒖉𒖊𒖋𒖌𒖍𒖎𒖏𒖐𒖑𒖒𒖓𒖔𒖕𒖖𒖗𒖘𒖙𒖚𒖛𒖜𒖝𒖞𒖟𒖠𒖡𒖢𒖣𒖤𒖥𒖦𒖧𒖨𒖩𒖪𒖫𒖬𒖭𒖮𒖯𒖰𒖱𒖲𒖳𒖴𒖵𒖶𒖷𒖸𒖹𒖺𒖻𒖼𒖽𒖾𒖿𒗀𒗁𒗂𒗃𒗄𒗅𒗆𒗇𒗈𒗉𒗊𒗋𒗌𒗍𒗎𒗏𒗐𒗑𒗒𒗓𒗔𒗕𒗖𒗗𒗘𒗙𒗚𒗛𒗜𒗝𒗞𒗟𒗠𒗡𒗢𒗣𒗤𒗥𒗦𒗧𒗨𒗩𒗪𒗫𒗬𒗭𒗮𒗯𒗰𒗱𒗲𒗳𒗴𒗵𒗶𒗷𒗸𒗹𒗺𒗻𒗼𒗽𒗾𒗿𒘀𒘁𒘂𒘃𒘄𒘅𒘆𒘇𒘈𒘉𒘊𒘋𒘌𒘍𒘎𒘏𒘐𒘑𒘒𒘓𒘔𒘕𒘖𒘗𒘘𒘙𒘚𒘛𒘜𒘝𒘞𒘟𒘠𒘡𒘢𒘣𒘤𒘥𒘦𒘧𒘨𒘩𒘪𒘫𒘬𒘭𒘮𒘯𒘰𒘱𒘲𒘳𒘴𒘵𒘶𒘷𒘸𒘹𒘺𒘻𒘼𒘽𒘾𒘿𒙀𒙁𒙂𒙃𒙄𒙅𒙆𒙇𒙈𒙉𒙊𒙋𒙌𒙍𒙎𒙏𒙐𒙑𒙒𒙓𒙔𒙕𒙖𒙗𒙘𒙙𒙚𒙛𒙜𒙝𒙞𒙟𒙠𒙡𒙢𒙣𒙤𒙥𒙦𒙧𒙨𒙩𒙪𒙫𒙬𒙭𒙮𒙯𒙰𒙱𒙲𒙳𒙴𒙵𒙶𒙷𒙸𒙹𒙺𒙻𒙼𒙽𒙾𒙿𒚀𒚁𒚂𒚃𒚄𒚅𒚆𒚇𒚈𒚉𒚊𒚋𒚌𒚍𒚎𒚏𒚐𒚑𒚒𒚓𒚔𒚕𒚖𒚗𒚘𒚙𒚚𒚛𒚜𒚝𒚞𒚟𒚠𒚡𒚢𒚣𒚤𒚥𒚦𒚧𒚨𒚩𒚪𒚫𒚬𒚭𒚮𒚯𒚰𒚱𒚲𒚳𒚴𒚵𒚶𒚷𒚸𒚹𒚺𒚻𒚼𒚽𒚾𒚿𒛀𒛁𒛂𒛃𒛄𒛅𒛆𒛇𒛈𒛉𒛊𒛋𒛌𒛍𒛎𒛏𒛐𒛑𒛒𒛓𒛔𒛕𒛖𒛗𒛘𒛙𒛚𒛛𒛜𒛝𒛞𒛟𒛠𒛡𒛢𒛣𒛤𒛥𒛦
# ...

# %%
#character ka no batata hai
y=ord('A')
print(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\data analytics\strings.ipynb Cell 22' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/data%20analytics/strings.ipynb#ch0000023?line=0'>1</a> #character ka no batata hai
# ----> <a href='vscode-notebook-cell:/d%3A/data%20analytics/strings.ipynb#ch0000023?line=1'>2</a> y=ord('Abdul Azeem Khan')
#       <a href='vscode-notebook-cell:/d%3A/data%20analytics/strings.ipynb#ch0000023?line=2'>3</a> print(y)
#
# TypeError: ord() expected a character, but string of length 16 found

# %%
y=ord('a')
print(y)
# Out:
# 97

# %%
y=ord('{')
print(y)
# Out:
# 123

# %%
for i in "Abdul Azeem Khan":
    y=ord(i)                              #khud se kia h sir ne nhi krwaya not necessary
    print(y,end='')
# Out:
# 65981001171083265122101101109327510497110

# %%
#concatenation
a="apple"
b="juice"
ab=a+b
print(ab)
# Out:
# applejuice

# %%
w1='this'
w2='is'
w3='amazing'
msg=w1+w2+w3
print(msg)
# Out:
# thisisamazing

# %%
msg=w1+' '+w2+' '+w3 #give space in the inverted comma as well otherwise no space in output
print(msg)
# Out:
# this is amazing

# %%
#duplication
word='Bismillah '
print(word*3)
# Out:
# Bismillah Bismillah Bismillah

# %%
print('-'*90)
# Out:
# ------------------------------------------------------------------------------------------

# %% [markdown]
# # methods
# -formatting
# -utility
# -validation

# %%
story="Once upon a time there was a kingdom, where peolple lived ,the end"

# %%
story.upper()
# Out:
# 'ONCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END'

# %%
story.lower()
# Out:
# 'once upon a time there was a kingdom, where peolple lived ,the end'

# %%
story.capitalize() #these methods are only temporary
# Out:
# 'Once upon a time there was a kingdom, where peolple lived ,the end'

# %%
print(story)
# Out:
# Once upon a time there was a kingdom, where peolple lived ,the end

# %%
story.title()
# Out:
# 'Once Upon A Time There Was A Kingdom, Where Peolple Lived ,The End'

# %%
story.swapcase()
# Out:
# 'oNCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END'

# %%
story.title().swapcase()  #this is called chaining of methods cuzz two methids used simultaeously
# Out:
# 'oNCE uPON a tIME tHERE wAS a kINGDOM, wHERE pEOLPLE lIVED ,tHE eND'

# %%
#for permanent change
story=story.upper()
print(story)
# Out:
# ONCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END

# %%
name="Samuel"
print(name)
# Out:
# Samuel

# %%
print(name.ljust(100))
# Out:
# Samuel

# %%
print(name.rjust(100))
# Out:
#                                                                                               Samuel

# %%
story.rjust(100)
# Out:
# '                                  ONCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END'

# %%
story.center(80,'✔')
# Out:
# '✔✔✔✔✔✔✔ONCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END✔✔✔✔✔✔✔'

# %% [markdown]
# # Validation

# %%
name=input('who are u?')
if not name.isalpha():
    print("name is invalid")
else:
    print("good job")
# Out:
# good job

# %%
"957957".isnumeric()
# Out:
# True

# %%
num=input('enter a number?')
if num.isnumeric():
    print("good job")
else:
    print("you dont know what a number is ")
# Out:
# good job

# %%
story.isupper()
# Out:
# True

# %%
story.islower()
# Out:
# False

# %%
x="myfile.png"
x.endswith('png')
# Out:
# True

# %%
name="Dr John Smith"
if name.startswith('Dr'):
    print('Welcome Doctor')
else:
    print('Doctor')
# Out:
# Welcome Doctor

# %% [markdown]
# # important stuff below
# split , join , strip , replace, count , find

# %%
story
# Out:
# 'ONCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END'

# %%
words=story.split()
print(words)
# Out:
# ['ONCE', 'UPON', 'A', 'TIME', 'THERE', 'WAS', 'A', 'KINGDOM,', 'WHERE', 'PEOLPLE', 'LIVED', ',THE', 'END']

# %%
story.split(',')
# Out:
# ['ONCE UPON A TIME THERE WAS A KINGDOM', ' WHERE PEOLPLE LIVED ', 'THE END']

# %%
story.split('A')  #split always returns a list
# Out:
# ['ONCE UPON ', ' TIME THERE W', 'S ', ' KINGDOM, WHERE PEOLPLE LIVED ,THE END']

# %%
len(story.split())
# Out:
# 13

# %%
message=['This','is','a','list']
s=''.join(message)
print(s)
# Out:
# Thisisalist

# %%
message=['This','is','a','list']
s='🐱‍🏍'.join(message)
print(s)
# Out:
# This🐱‍🏍is🐱‍🏍a🐱‍🏍list

# %% [markdown]
# # strip
# it removes leading and trailing spaces not in between

# %%
password=input('enter the password')
print(len(password),password)
password=password.strip()
print(len(password),password)
# Out:
# 20   437658 3r7i59
# 13 437658 3r7i59

# %%
story
# Out:
# 'ONCE UPON A TIME THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END'

# %%
story.replace('E','A')
# Out:
# 'ONCA UPON A TIMA THARA WAS A KINGDOM, WHARA PAOLPLA LIVAD ,THA AND'

# %%
story.replace('TIME','DATE')
# Out:
# 'ONCE UPON A DATE THERE WAS A KINGDOM, WHERE PEOLPLE LIVED ,THE END'

# %%
story.replace('THE','')
# Out:
# 'ONCE UPON A TIME RE WAS A KINGDOM, WHERE PEOLPLE LIVED , END'

# %%
another_story="This is an example of another story, this story is not simple and is not very long,but it is a story"

# %%
another_story.count('story')
# Out:
# 3

# %%
another_story.count('is')
# Out:
# 6

# %%
another_story.find('another')
# Out:
# 22

# %%
another_story.find('story') #gives only the fiorst occuurence
# Out:
# 30

# %%
another_story.rfind('story')
# Out:
# 95
